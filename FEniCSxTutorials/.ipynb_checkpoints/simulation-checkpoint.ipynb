# %%
from mpi4py import MPI
from petsc4py import PETSc

from tqdm.notebook import tqdm_notebook

import numpy as np

import ufl

from dolfinx import fem, io, mesh, plot, la
from dolfinx.fem.petsc import assemble_matrix, create_vector, apply_lifting
from basix.ufl import element, mixed_element
from dolfinx.io import XDMFFile

import pyvista

# %% [markdown]
# https://www.wias-berlin.de/people/john/BETREUUNG/master_ding.pdf
# https://www.youtube.com/watch?v=LflB3-bEK2M
# http://redbkit.github.io/redbKIT/math/AdvDiffReact/#id

# %%
compounds = [ 'pt', 'th', 'at', 'fg', 'rp', 'ap', 'bp', 'fi' ] 
compounds_inital = [1400, 0, 2410, 7000, 1000, 50, 0, 0]
compounds_diffusion = {'pt': 5.21e-7, 'th' : 6.47e-7, 'at' : 5.57e-7, 'fg' : 3.10e-7, 'rp' : 2.5e-7, 'ap' : 2.5e-7, 'bp' : 0, 'fi' : 2.47e-7}
C = {'pt': 0, 'th' : 1, 'at' : 2, 'fg' : 3, 'rp' : 4, 'ap' : 5, 'bp' : 6, 'fi' : 7}
k_rp_th = 6.5e-10
k_ap_th = 3.69e-9
k_bp_th = 6.5e-10
k_at_th = 7.083e-3
k_th_fi = 59
k_th_Mfi = 3160
k_th_pa = 0.5
k_ap_pa = 0.3
k_bp = 1e4
k_bp_pa = 0.30
C_fi_50 = 60
C_th_50 = 0.911

# %%
# create mesh for calculations to take place in
msh = mesh.create_unit_square(MPI.COMM_WORLD, 16,16)

# define elements to be used for the velocity and the distribution
z_p1 = element("P", msh.basix_cell(), 1)
v_p2 = element("P", msh.basix_cell(), 2, shape=(msh.geometry.dim,))

# define mixed element and function space to be used when there are multiple compounds.
ME = mixed_element([z_p1, z_p1, z_p1, z_p1, z_p1, z_p1, z_p1, z_p1])
ZMixed = fem.FunctionSpace(msh, ME)

# Define function spaces to be used for the two variables
# Z = fem.FunctionSpace(msh, z_p1)
V = fem.FunctionSpace(msh, v_p2)

# %%
# define functions to be used for boundaries and initials
def initial_condition(x, a=5):
    return np.exp(-a * (x[0]**2 + x[1]**2))

def initial_condition_2(x, a=5):
    return np.exp(-a * (x[0]**2 + (x[1]-1)**2))

def flow(x):
    return np.stack((np.zeros(x.shape[1]), np.zeros(x.shape[1]))) 
    
# Function to mark the lid (y = 1)
def lid(x):
    return np.isclose(x[1], 1)

def inflow_point(x):
    return np.isclose(x[0], 0) & np.isclose(x[1], 0.5)

# define time step variables 
T = 1.3          # final time
num_steps = 1300   # number of time steps
dt = T / num_steps # time step size

# %%
# # define boundary conditions
# inflow_dofs = fem.locate_dofs_geometrical(Z, lid)
# bc_inflow = fem.dirichletbc(PETSc.ScalarType(1), inflow_dofs, Z)
# bc_outlfow = fem.dirichletbc(PETSc.ScalarType(-1), inflow_dofs, Z)

# # order here is important as want to apply outflow before the inflow
# bcs = [bc_outlfow, bc_inflow]
bcs = []

# %%
# Create variables for results at current and previous timesteps
s_ = fem.Function(ZMixed)
# s_.interpolate(initial_condition)
s_n = fem.Function(ZMixed)
# s_n.interpolate(initial_condition)

sx_ = [s_.sub(x) for x in range(8)]
sx_n = [s_n.sub(x) for x in range(8)]

# s1_.name = "s1"
# s2_.name = "s2"
# s3_.name = "s3"

# sx_[0].interpolate(initial_condition)
# sx_n[0].interpolate(initial_condition)
# sx_[1].interpolate(initial_condition_2)
# sx_n[1].interpolate(initial_condition_2)

# s3_.x.array[:] = 0
# s3_n.x.array[:] = 0

for compound, x in C.items():
    val = compounds_inital[x]
    sx_[x].interpolate(lambda x: np.full((x.shape[1],), val))
    sx_n[x].interpolate(lambda x: np.full((x.shape[1],), val))
    s_.sub(x).name = compound




# very basic flow variable
u_n = fem.Function(V)
u_n.interpolate(flow)

# create trial and test functions
sx = ufl.TrialFunctions(ZMixed)
zx = ufl.TestFunctions(ZMixed)

# %%
# https://github.com/unifem/fenics-notes/blob/master/notebooks/advection-diffusion-reaction.ipynb
# https://jsdokken.com/dolfinx-tutorial/chapter2/diffusion_code.html

# other constants:
k_rp_th = fem.Constant(msh, PETSc.ScalarType(k_rp_th))
k_ap_th = fem.Constant(msh, PETSc.ScalarType(k_ap_th))
k_bp_th = fem.Constant(msh, PETSc.ScalarType(k_bp_th))
k_at_th = fem.Constant(msh, PETSc.ScalarType(k_at_th))
k_th_fi = fem.Constant(msh, PETSc.ScalarType(k_th_fi))
k_th_Mfi = fem.Constant(msh, PETSc.ScalarType(k_th_Mfi))
k_th_pa = fem.Constant(msh, PETSc.ScalarType(k_th_pa))
k_ap_pa = fem.Constant(msh, PETSc.ScalarType(k_ap_pa))
k_bp = fem.Constant(msh, PETSc.ScalarType(k_bp))
k_bp_pa = fem.Constant(msh, PETSc.ScalarType(k_bp_pa))
C_fi_50 = fem.Constant(msh, PETSc.ScalarType(C_fi_50))
C_th_50 = fem.Constant(msh, PETSc.ScalarType(C_th_50))

for key in compounds_diffusion.keys():
    compounds_diffusion[key] = fem.Constant(msh, PETSc.ScalarType(compounds_diffusion[key]))

# constants for calculations
rho = fem.Constant(msh, PETSc.ScalarType(1)) # advection coefficent
eps = fem.Constant(msh, PETSc.ScalarType(1)) # diffusion coefficent
k = fem.Constant(msh, dt)
fs = fem.Constant(msh, PETSc.ScalarType(0))
K = fem.Constant(msh, PETSc.ScalarType(1)) # reaction coefficent

F = 0

# https://fenicsproject.discourse.group/t/navier-stokes-and-convection-diffusion/7170
for compound, i in C.items():
    F += ( ( sx[i] - sx_n[i] ) / k ) * zx[i] * ufl.dx # advective terms
    F += ufl.dot( u_n, ufl.grad( sx_n[i] ) ) * zx[i] * ufl.dx # advective terms
    F += compounds_diffusion[compound] * ufl.dot( ufl.grad(sx[i] ), ufl.grad( zx[i] ) ) * ufl.dx # diffusive term
    F -= fs * zx[i] * ufl.dx

# reactive terms
F -= - k_rp_th * sx_[C['rp']] * sx_[C['pt']] * zx[C['pt']] * ufl.dx \
     - k_ap_th * sx_[C['ap']] * sx_[C['pt']] * zx[C['pt']] * ufl.dx \
     - k_bp_th * sx_[C['bp']] * sx_[C['pt']] * zx[C['pt']] * ufl.dx

F -= k_rp_th * sx_[C['rp']] * sx_[C['pt']] * zx[C['th']] * ufl.dx \
    + k_ap_th * sx_[C['ap']] * sx_[C['pt']] * zx[C['th']] * ufl.dx \
    + k_bp_th * sx_[C['bp']] * sx_[C['pt']] * zx[C['th']] * ufl.dx \
    - k_at_th * sx_[C['at']] * sx_[C['th']] * zx[C['th']] * ufl.dx

F -= - k_at_th * sx_[C['at']] * sx_[C['th']] * zx[C['at']] * ufl.dx

F -= - k_th_fi * sx_[C['th']] * ( sx_[C['fg']] / ( k_th_Mfi + sx_[C['fg']] ) ) * zx[C['fg']] * ufl.dx

F -= - k_th_pa * (sx_[C['th']] / (sx_[C['th']]**4 + C_th_50**4) ) * sx_[C['rp']] * zx[C['rp']] * ufl.dx \
    - k_ap_pa * sx_[C['rp']] * sx_[C['ap']] * zx[C['rp']] * ufl.dx \
    - k_bp_pa * sx_[C['rp']] * sx_[C['bp']] * zx[C['rp']] * ufl.dx

F -= k_th_pa * (sx_[C['th']]**4 / (sx_[C['th']]**4 + C_th_50**4) ) * sx_[C['rp']] * zx[C['ap']] * ufl.dx \
    + k_ap_pa * sx_[C['rp']] * sx_[C['ap']] * zx[C['ap']] * ufl.dx \
    + k_bp_pa * sx_[C['rp']] * sx_[C['bp']] * zx[C['ap']] * ufl.dx \
    - k_bp * (sx_[C['fi']]**4 / (sx_[C['fi']]**4 + C_fi_50**4) ) * sx_[C['ap']] * zx[C['ap']] * ufl.dx

F -= k_bp * (sx_[C['fi']]**4 / (sx_[C['fi']]**4 + C_fi_50**4) ) * sx_[C['ap']] * zx[C['bp']] * ufl.dx

F -= k_th_fi * sx_[C['th']] * ( sx_[C['fg']] / ( k_th_Mfi + sx_[C['fg']] ) ) * zx[C['fi']] * ufl.dx



a = fem.form(ufl.lhs(F))
L = fem.form(ufl.rhs(F))

# Just diffusion equation
# https://jsdokken.com/dolfinx-tutorial/chapte400r2/diffusion_code.html
# a = fem.form(s * z * ufl.dx + dt * ufl.dot(ufl.grad(s), ufl.grad(z)) * ufl.dx)
# L = fem.form((s_n + dt * fs) * z * ufl.dx)

# create parts of the equation that will not change between timesteps
# https://fenicsproject.discourse.group/t/how-to-set-bcs-for-petsc-matrices-and-petsc-vectors-in-dolfinx/4135
A = assemble_matrix(a, bcs=bcs)
A.assemble()
b = create_vector(L)

# create solver for the linear (matrix) problem
## Using petsc4py to create a linear solver
# As we have already assembled `a` into tbhe matrix `A`, we can no longer use the `dolfinx.fem.petsc.LinearProblem` class to solve the problem. Therefore, we create a linear algebra solver using PETSc, and assign the matrix `A` to the solver, and choose the solution strategy.
solver2 = PETSc.KSP().create(msh.comm)
solver2.setOperators(A)
solver2.setType(PETSc.KSP.Type.PREONLY)
solver2.getPC().setType(PETSc.PC.Type.LU)

# %%
# https://jsdokken.com/dolfinx-tutorial/chapter2/diffusion_code.html
# create output file
# files = {}

# for compound in C.keys():
#     files[compound] = io.XDMFFile(msh.comm, f"results/sim/{compound}.xdmf", "w")
#     files[compound].write_mesh(msh)
# xdmf0 = io.XDMFFile(msh.comm, "results/sim/0.xdmf", "w")
# xdmf1 = io.XDMFFile(msh.comm, "results/sim/1.xdmf", "w")
# xdmf2 = io.XDMFFile(msh.comm, "results/sim/2.xdmf", "w")

# xdmf0.write_mesh(msh)
# xdmf1.write_mesh(msh)
# xdmf2.write_mesh(msh)

# for compound, index in C.items():
#     files[compound].write_function(s_.sub(index),0)

output = io.XDMFFile(msh.comm, f"results/sim/combined.xdmf", "w")
#output.parameters.update( { "functions_share_mesh": True, "rewrite_function_mesh": False } )
# Out:
# HDF5-DIAG: Error detected in HDF5 (1.14.3) MPI-process 0:
#   #000: H5F.c line 660 in H5Fcreate(): unable to synchronously create file
#     major: File accessibility
#     minor: Unable to create file
#   #001: H5F.c line 614 in H5F__create_api_common(): unable to create file
#     major: File accessibility
#     minor: Unable to open file
#   #002: H5VLcallback.c line 3605 in H5VL_file_create(): file create failed
#     major: Virtual Object Layer
#     minor: Unable to create file
#   #003: H5VLcallback.c line 3571 in H5VL__file_create(): file create failed
#     major: Virtual Object Layer
#     minor: Unable to create file
#   #004: H5VLnative_file.c line 94 in H5VL__native_file_create(): unable to create file
#     major: File accessibility
#     minor: Unable to open file
#   #005: H5Fint.c line 1870 in H5F_open(): unable to truncate a file which is already open
#     major: File accessibility
#     minor: Unable to open file
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 19
#       1 # https://jsdokken.com/dolfinx-tutorial/chapter2/diffusion_code.html
#       2 # create output file
#       3 # files = {}
#    (...)
#      16 # for compound, index in C.items():
#      17 #     files[compound].write_function(s_.sub(index),0)
# ---> 19 output = io.XDMFFile(msh.comm, f"results/sim/combined.xdmf", "w")
#      20 #output.parameters.update( { "functions_share_mesh": True, "rewrite_function_mesh": False } )
#
# RuntimeError: Failed to create HDF5 file.

# %%
# inital time
times = []
timeSeries = {}

t = 0
times.append(t)
for compound, index in C.items():
    val = s_.sub( index ).collapse()
    val.name = compound
    output.write_function( val, t )

    
    timeSeries[compound] = [val.x.array[0]]
    print(f"[{compound}]->{val.x.array[0]}")
# xdmf0.write_function(s_.sub(0), t)
# xdmf1.write_function(s_.sub(1), t)
# xdmf2.write_function(s_.sub(2), t)

for i in tqdm_notebook(range(num_steps)):
    t += dt # update time

    # https://jsdokken.com/dolfinx-tutorial/chapter2/diffusion_code.html
    # Update the right hand side reusing the initial vector
    with b.localForm() as loc_b:
        loc_b.set(0)
    fem.petsc.assemble_vector(b, L)
    apply_lifting(b, [a], [bcs])
    b.ghostUpdate(addv=PETSc.InsertMode.ADD, mode=PETSc.ScatterMode.REVERSE)
    fem.set_bc(b, bcs)

    # solve
    solver2.solve(b, s_.vector)
    s_.x.scatter_forward() # correct for inacuracies 

    s_n.x.array[:] = s_.x.array # update previous step

    # xdmf0.write_function(s_.sub(0),t)
    # xdmf1.write_function(s_.sub(1), t)
    # xdmf2.write_function(s_.sub(2), t)
    outputting = True
    times.append(t)
    for compound, index in C.items():
        val = s_.sub( index ).collapse()
        val.name = compound
        output.write_function( val, t )

        
        timeSeries[compound].append(val.x.array[0])

    #     if (outputting == True):
    #         val = s_.sub( index ).collapse().x.array[0]
    #         if ( np.isnan(val) ):
    #             outputting = False
    #         print(f"[{compound}]->{s_.sub( index ).collapse().x.array[0]}")
    # print("---------------------------------------------------")
# xdmf0.close()
# xdmf1.close()
# xdmf2.close()
# for compound in C.keys():
#     files[compound].close()

output.close()
# Out:
# [pt]->1399.9929962630372
# [th]->0.0003177667514324688
# [at]->2409.9933140292296
# [fg]->6999.984078389308
# [rp]->1.7793705807376244e-209
# [ap]->1049.9999134236903
# [bp]->1.2808765866131507e-08
# [fi]->0.0159216060981757
# 2024-04-17 12:06:58.350 (2654.996s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.354 (2654.999s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.356 (2655.002s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.358 (2655.004s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.360 (2655.006s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.362 (2655.008s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.364 (2655.010s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.366 (2655.012s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
#   0%|          | 0/1300 [00:00<?, ?it/s]
# 2024-04-17 12:06:58.400 (2655.046s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.402 (2655.047s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.432 (2655.078s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.501 (2655.147s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.542 (2655.188s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.572 (2655.217s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.641 (2655.287s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.688 (2655.334s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.750 (2655.396s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.784 (2655.430s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.853 (2655.499s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.904 (2655.549s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.933 (2655.579s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:58.984 (2655.629s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.032 (2655.678s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.085 (2655.730s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.135 (2655.781s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.264 (2655.910s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.367 (2656.013s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.421 (2656.066s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.512 (2656.158s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.569 (2656.215s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.662 (2656.308s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.757 (2656.402s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.794 (2656.440s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.827 (2656.473s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.847 (2656.492s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.867 (2656.513s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.884 (2656.530s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.906 (2656.552s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.928 (2656.574s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.948 (2656.593s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.986 (2656.632s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:06:59.994 (2656.640s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.016 (2656.662s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.043 (2656.688s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.062 (2656.707s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.084 (2656.729s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.106 (2656.752s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.128 (2656.774s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.159 (2656.804s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.167 (2656.812s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.189 (2656.834s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.210 (2656.856s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.232 (2656.878s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.247 (2656.893s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.267 (2656.912s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.277 (2656.923s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.308 (2656.954s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.312 (2656.958s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.323 (2656.969s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.339 (2656.985s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.349 (2656.995s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.360 (2657.006s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.377 (2657.023s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.388 (2657.034s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.418 (2657.064s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.421 (2657.066s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.438 (2657.084s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.449 (2657.094s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.459 (2657.104s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.476 (2657.122s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.487 (2657.133s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.496 (2657.142s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.521 (2657.167s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.523 (2657.169s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.540 (2657.186s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.552 (2657.197s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.569 (2657.215s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.580 (2657.225s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.590 (2657.235s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.607 (2657.253s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.630 (2657.275s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.636 (2657.282s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.648 (2657.294s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.665 (2657.310s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.675 (2657.321s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.693 (2657.339s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.704 (2657.349s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.715 (2657.360s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.744 (2657.390s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.746 (2657.392s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.757 (2657.403s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.774 (2657.420s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.785 (2657.430s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.794 (2657.439s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.809 (2657.454s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.819 (2657.465s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.848 (2657.494s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.850 (2657.495s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.869 (2657.514s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.880 (2657.525s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.890 (2657.536s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.907 (2657.553s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.917 (2657.563s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.935 (2657.581s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.956 (2657.602s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.963 (2657.609s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.974 (2657.620s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:00.985 (2657.631s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.003 (2657.649s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.025 (2657.671s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.036 (2657.682s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.060 (2657.706s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.092 (2657.738s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.094 (2657.740s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.113 (2657.759s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.124 (2657.770s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.135 (2657.780s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.152 (2657.797s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.175 (2657.821s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.210 (2657.855s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.243 (2657.889s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.246 (2657.891s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.266 (2657.911s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.278 (2657.924s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.287 (2657.933s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.306 (2657.952s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.316 (2657.962s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.325 (2657.971s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.350 (2657.996s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.353 (2657.998s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.383 (2658.028s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.404 (2658.050s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.418 (2658.063s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.436 (2658.082s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.446 (2658.092s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.464 (2658.110s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.485 (2658.131s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.487 (2658.133s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.507 (2658.153s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.518 (2658.164s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.529 (2658.175s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.546 (2658.191s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.570 (2658.216s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.594 (2658.240s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.635 (2658.280s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.637 (2658.283s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.646 (2658.292s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.662 (2658.308s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.672 (2658.318s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.691 (2658.336s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.701 (2658.347s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.710 (2658.356s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.739 (2658.385s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.741 (2658.387s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.751 (2658.397s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.766 (2658.412s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.778 (2658.424s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.795 (2658.441s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.806 (2658.452s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.816 (2658.462s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.846 (2658.491s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.848 (2658.494s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.859 (2658.505s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.877 (2658.523s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.888 (2658.534s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.897 (2658.543s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.914 (2658.560s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.938 (2658.584s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.959 (2658.604s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.966 (2658.611s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.978 (2658.624s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:01.988 (2658.633s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.005 (2658.651s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.016 (2658.661s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.027 (2658.673s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.045 (2658.690s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.066 (2658.711s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.068 (2658.714s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.088 (2658.734s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.112 (2658.757s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.120 (2658.766s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.135 (2658.781s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.147 (2658.793s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.157 (2658.803s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.187 (2658.833s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.190 (2658.836s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.201 (2658.846s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.219 (2658.865s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.230 (2658.876s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.241 (2658.887s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.260 (2658.906s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.284 (2658.930s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.305 (2658.951s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.313 (2658.959s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.324 (2658.970s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.333 (2658.979s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.349 (2658.995s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.360 (2659.006s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.371 (2659.017s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.389 (2659.035s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.415 (2659.061s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.418 (2659.064s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.430 (2659.076s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.448 (2659.093s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.472 (2659.118s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.491 (2659.136s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.502 (2659.148s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.513 (2659.158s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.540 (2659.186s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.592 (2659.237s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.609 (2659.254s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.641 (2659.287s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.656 (2659.302s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.689 (2659.334s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.718 (2659.364s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.737 (2659.382s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.763 (2659.408s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.771 (2659.417s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.790 (2659.435s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.808 (2659.453s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.825 (2659.471s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.846 (2659.492s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.857 (2659.502s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.876 (2659.522s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.898 (2659.543s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.916 (2659.562s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.927 (2659.573s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.943 (2659.589s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.956 (2659.601s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.971 (2659.616s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:02.987 (2659.633s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.006 (2659.652s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.026 (2659.672s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.034 (2659.680s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.046 (2659.692s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.076 (2659.721s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.089 (2659.734s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.119 (2659.764s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.143 (2659.789s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.159 (2659.805s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.183 (2659.828s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.186 (2659.831s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.206 (2659.851s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.227 (2659.872s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.238 (2659.884s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.255 (2659.901s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.266 (2659.912s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.284 (2659.930s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.311 (2659.957s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.315 (2659.960s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.327 (2659.973s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.345 (2659.991s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.364 (2660.010s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.377 (2660.022s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.392 (2660.038s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.413 (2660.058s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.434 (2660.079s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.444 (2660.089s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.455 (2660.100s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.474 (2660.120s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.496 (2660.142s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.524 (2660.169s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.536 (2660.181s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.554 (2660.199s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.588 (2660.233s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.590 (2660.236s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.611 (2660.257s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.626 (2660.272s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.646 (2660.292s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.661 (2660.307s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.683 (2660.329s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!
# 2024-04-17 12:07:03.703 (2660.349s) [main            ]           XDMFFile.cpp:256   WARN| No mesh found at '/Xdmf/Domain/Grid[@GridType='Uniform'][1]'. Write mesh before function!

# %%
import matplotlib.pyplot as plt

fig, (ax1, ax2) = plt.subplots(1, 2)

for compound, index in C.items():
    ax1.plot(times, timeSeries[compound], label = compound)

for compound in ['th', 'fi', 'bp']:
    ax2.plot(times, timeSeries[compound], label = compound)

ax1.legend()
ax2.legend()
fig.set_figwidth(10)

fig.savefig("results/sim/timeSeries.png")


# timeSeries['th']

# %%
# visualisation
pyvista.set_jupyter_backend('client')

pyvista.start_xvfb()

dist1, test = ZMixed.sub(2).collapse()

topologyZ, cell_typesZ, geometryZ = plot.vtk_mesh(dist1)
grid0 = pyvista.UnstructuredGrid(topologyZ, cell_typesZ, geometryZ)
grid0.point_data["s0"] = s_n.sub(2).collapse().x.array

grid1 = pyvista.UnstructuredGrid(topologyZ, cell_typesZ, geometryZ)
grid1.point_data["s1"] = s_.sub(2).collapse().x.array

topologyV, cell_typesV, geometryV = plot.vtk_mesh(V)
values = np.zeros((geometryV.shape[0], 3), dtype=np.float64)
values[:, :len(u_n)] = u_n.x.array.real.reshape((geometryV.shape[0], len(u_n)))
velocity_grid = pyvista.UnstructuredGrid(topologyV, cell_typesV, geometryV)
velocity_grid["u"] = values
# Create a point cloud of glyphs
glyphs = velocity_grid.glyph(orient="u", factor=0.2)

plotter = pyvista.Plotter(notebook=True, shape=(1, 2))
plotter.subplot(0,0)
plotter.add_mesh(grid0, show_edges=True)
plotter.view_xy()
plotter.subplot (0,1)
plotter.add_mesh(grid1, show_edges=True)
plotter.view_xy()
#plotter.add_mesh(glyphs)

plotter.show()
# Out:
# Widget(value='<iframe src="http://localhost:43353/index.html?ui=P_0x7f50e1c10a60_1&reconnect=auto" class="pyvi…

# %%
# f = fem.Constant(msh, PETSc.ScalarType(0))
# a = u * v * ufl.dx + dt * ufl.dot(ufl.grad(u), ufl.grad(v)) * ufl.dx
# L = (u_n + dt * f) * v * ufl.dx
